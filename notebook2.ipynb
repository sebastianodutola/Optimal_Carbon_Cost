# %%
import numpy as np
import pandas as pd
df = pd.DataFrame(['2026-02-24T10:00Z','2026-02-24T10:00Z'])
times = df[0].apply(np.datetime64).to_numpy()
times
# Out:
# /Users/sebastianodutola/.virtualenvs/datascience/lib/python3.11/site-packages/pandas/core/algorithms.py:1743: UserWarning: no explicit representation of timezones available for np.datetime64
#   return lib.map_infer(values, mapper, convert=convert)
# array(['2026-02-24T10:00:00.000000000', '2026-02-24T10:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
a = np.timedelta64(35, 'm')
a.astype('timedelta64[s]')
# Out:
# np.timedelta64(2100,'s')

# %%
a = np.datetime64('2001-09-11T07:30')
b = np.datetime64('2001-09-11T08:00:00.00000000')
a-b
# Out:
# np.timedelta64(-1800000000000,'ns')
